# %% [markdown]
# <a href="https://colab.research.google.com/github/dinakeshvari/NLP_Exercise_ShokrzadCourse/blob/main/Project01_DS04_S01_NLTK_SpaCy_RezaShokrzad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📜 Project: Job Description Analyzer – Extracting Required Skills from Job Postings

# %% [markdown]
# ## 📌 Objective
# Use spaCy’s Named Entity Recognition (NER) and NLTK preprocessing to extract and categorize required skills from job descriptions. The goal is to identify trends in job requirements and analyze the most in-demand skills across industries.

# %% [markdown]
# ## 🛠️ Project Steps & Instructions

# %%
#📥 Download the Dataset
# !wget https://raw.githubusercontent.com/binoydutt/Resume-Job-Description-Matching/refs/heads/master/data.csv
# Out:
# --2025-04-18 13:31:47--  https://raw.githubusercontent.com/binoydutt/Resume-Job-Description-Matching/refs/heads/master/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 646072 (631K) [text/plain]
# Saving to: ‘data.csv’
#
# data.csv            100%[===================>] 630.93K  --.-KB/s    in 0.03s
#
# 2025-04-18 13:31:47 (19.3 MB/s) - ‘data.csv’ saved [646072/646072]

# %% [markdown]
# ### Step 1: Load the Dataset
# #### 📌 Dataset: A provided CSV file containing job descriptions from different industries (IT, Healthcare, Finance, Marketing, etc.).
#
# 1. Download the dataset (link below).
# 2. Load it into Python using Pandas.
# 3. View the first few rows to understand its structure.

# %%
# your code here
import pandas as pd
data = pd.read_csv('data.csv')
data.head()
# Out:
#    Unnamed: 0                          company  \
# 0           1          Visual BI Solutions Inc
# 1           2                       Jobvertise
# 2           3           Santander Consumer USA
# 3           4   Federal Reserve Bank of Dallas
# 4           5                           Aviall
#
#                                             position  \
# 0  Graduate Intern (Summer 2017) - SAP BI / Big D...
# 1                          Digital Marketing Manager
# 2    Manager, Pricing Management Information Systems
# 3               Treasury Services Analyst Internship
# 4                              Intern, Sales Analyst
#
#                                                  url     location  \
# 0  https://www.glassdoor.com/partner/jobListing.h...    Plano, TX
# 1  https://www.glassdoor.com/partner/jobListing.h...   Dallas, TX
# 2  https://www.glassdoor.com/partner/jobListing.h...   Dallas, TX
# 3  https://www.glassdoor.com/partner/jobListing.h...   Dallas, TX
# 4  https://www.glassdoor.com/partner/jobListing.h...   Dallas, TX
#
#        headquaters                employees founded  \
# 0        Plano, TX      51 to 200 employees    2010
# 1  Berlin, Germany        1 to 50 employees    2011
# 2       Dallas, TX  5001 to 10000 employees    1995
# 3       Dallas, TX   1001 to 5000 employees    1914
# 4       Dallas, TX   1001 to 5000 employees  Boeing
#
#                          industry  \
# 0          Information Technology
# 1                         Unknown
# 2                         Finance
# 3                         Finance
# 4  Subsidiary or Business Segment
#
#                                      Job Description
# 0   Location: Plano, TX or Oklahoma City, OK Dura...
# 1   The Digital Marketing Manager is the front li...
# 2   Summary of Responsibilities:The Manager Prici...
# 3   ORGANIZATIONAL SUMMARY:   As part of the nati...
# 4     Aviall is the world's largest provider of n...

# %% [markdown]
# ### Step 2: Preprocessing the Job Descriptions
# #### 📌 Goal: Clean the text by removing stopwords, punctuation, and unnecessary characters.
#
# 1. Use NLTK to tokenize the descriptions.
# 2. Remove stopwords and special characters.
# 3. Convert text to lowercase for consistency.

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'company', 'position', 'url', 'location', 'headquaters',
#        'employees', 'founded', 'industry', 'Job Description'],
#       dtype='object')

# %%
# your code here
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

nltk.download('stopwords')
nltk.download('punkt')
nltk.download('punkt_tab')
descriptoins = data['Job Description']
stop_words = set(stopwords.words('english'))
preprocessed_descriptions = []
for description in descriptoins:
  words = word_tokenize(description.lower())
  filtered_words = [word for word in words if word not in stop_words]
  preprocessed_descriptions.append(' '.join(filtered_words))
preprocessed_descriptions
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ["location : plano , tx oklahoma city , ok duration : internship summer 2017 term job summary : visual bi solutions inc seeking graduate interns strong expertise/passion bi big data & analytics solutions ( sap bw sap hana oracle / ms sql edw / pl/sql / bods / sas / big data / visualization tools ) join college recruiting hiring program . role , would building best-in-class bi , analytics & big data solutions would consumed leaders executives fortune 500 organizations . strong sense business analysis , etl , data modeling , data warehousing , visualization , reporting , advanced analytics data interpretation key attributes look . market leader sap bi & analytics - visual bi selective student hiring candidates portfolio non-academic project work/technical blogs preferred work experience academic gpa scores . asked hone bi & analytics expertise internship working best customers bi talent world requirements-2+ years bi / edw / etl / big data development relevant work bi/datawarehousing experience preferred -visual bi consider non-academic projects showcase experience areas -experience sap hana sap bw sap bods big data frameworks ( hadoop/spark , .. ) plus- candidates reporting web development skills ( css/javascript/ui5/fiori ) also considerebenefits forefront learning innovation ! 'll 24x7 access visual bi labs , learning environment hosts leading-edge innovations bi excellent training development opportunities internship 10 - 12 weeks paid internship opportunities secure full-time roles bi & analytics visual bi",
#  'digital marketing manager front line patient , consumer audience engagement eyecare services partners affiliates , leading defining digital marketing mix , emphasis social media , web , email content marketing . digital marketing manager work closely cross functional teams plan execute high impact marketing strategies designed drive results.essential functions execute digital brand presence social media , web , email strategies , implementing best practices utilizing data insights continued evolution understand digital platforms upcoming trends ability foster tangible action brand leverage brand consumer/patient insight engage foster stronger consumer engagement across digital platforms lead project based marketing initiatives influencer engagement campaigns manage day-to-day communications internal teams , brands , partners , patients/consumers oversee practice website redesign introduce patient communication software ( solution reach ) introduce assist internet marketing packages ( glacial ) manage content corporate web site manage digital ( organic paid ) channels , track , analyze digital marketing efforts create marketing collateral needed corporate practices ( i.e . trade show banners , email blasts , flyers , posters , ads , concepts radio , seasonal campaigns specialty services , lasik , cosmetic , piols , kamra , cataracts , flex spending , back school exams and/or glasses ) requirements bachelors degree 5+ years related work experience digital marketing , content marketing , social media , copy writing required hands-on role requires excellent collaborative , organizational , creative skills ability build strategy execute across multiple digital disciplines strong experience digital content across platforms , clear understanding content conceptualized , created , promoted experience working digital media based data analytics , turn insights actions strong understanding digital marketing across disciplines including social , search , email websites content experience managing maintaining content driven websites , email social media channels strong writer capable internalizing articulating brand voice , clearly present ideas points view internal teams',
#  'summary responsibilities : manager pricing mis responsible assisting pricing & strategy profitability teams within decision sciences execution information gathering reporting . manager pricing mis responsible managing development production pricing reporting supervising analysts responsible converting existing daily , weekly , monthly ad-hoc reports efficient delivery tools includes data visualization . supervision portion pricing mis team require leadership direction timely internal regulatory , ongoing ad-hoc reporting support pricing & strategy profitability segments within decision sciences . consistency quality information reports along repository management critical.essential job functions : responsible assisting decision sciences team design , development , implementation production pricing reporting needs ongoing ad-hoc environmentadditionally responsible managing automation implementation process new reports , appropriate , converting existing business usual reports automated delivery process.responsible working information technology organization , assigned consultants existing staff develop governance process converting appropriate reports efficient data visualization mechanism.drive , adopt develop best practices report templates toolsestablish manage pricing governance team drive location , sharepoint sites repository documentsassure clear , concise objective reportingidentify escalate issues observations ariseother functions : maintain ongoing relationships management throughout organization effectively manage motivate teamcomplete reviews/projects additional work within specified timescales line departmental standardsresponsible aspects team members life cycle including , recruitment , performance management , development coachingensure tasks carried high degree professionalism.daily support junior analysts interns relative production reporting deliverables.requirements : bachelors degree computer mis related field , equivalent combination education experience , required.one ( 1 ) three ( 3 ) years previous management experience required 3 years specific auto industry experience working reporting environment.internal candidates meet stated requirements management experience ( , otherwise qualified ) may selected role contingent upon completion prescribed training plan.3 -5 years progressively responsible experience within financial services management mis within financial services institution requiredexpertise pc software applications sql , sas , excel , word , powerpoint , access dashboardsexperience tableau similar data visualization tools plusdetailed knowledge information reporting structures ( extraction , transformation loading ( etls ) , data management , data warehouse , data validation models etc . ) knowledge financial statements , accounting principles , credit policy , applicable laws industry data sources.dedication information integrity accurate reportingexcellent analytical , technical problem solving skills , strong attention detailability effectively explain others understand approach complicated issuesexceptional verbal written communication , collaboration , time management skillspossess strong leadership skills focus development mentorshipability adapt various work environments project schedulesability work effectively team environment levels personnelself-directed ability multitask prioritizeability maintain strict confidentialitysuperior leadership organizational skillsstrategic tactical thinkerworking conditions : extended working hours may required dictated management business needs.travel multiple facilities may required.may required lift , push , pull materials weighing twenty ( 20 ) pounds.may required sit review information computer screen long periods time.may require repetitive motions hands wrist related writing typing electronic keyboard.corporate / satellite office role.employers rights : job description list duties job . may asked supervisors managers perform duties . evaluate ...
#  'organizational summary : part nation ’ central bank , federal reserve bank dallas committed strengthening economy communities . fed , opportunity become part important public service institution whose work touches lives across globe . ’ big job ’ need talented , results-driven professionals care making difference . position summary : treasury services intern federal reserve bank dallas treasury services department , regularly apply analytical , problem solving , written interpersonal skills . opportunity expand knowledge project operations management , process improvement , learn various areas team environment . responsibilities : organize department training data usable outline electronic handbook examine unstructured data identify deleted retained assist physical inventory organization storage areas analyze process patching computers maintain security controls automate reporting vendor scorecards utilize creativity designing marketing materials work ad hoc assignments , requested participate meetings trainings , assigned education experience : strong writing skills , including ability write clearly , correctly , concisely ability analyze problems inquiries ability prioritize tasks projects meet business needs logical sequence ability maintain flexibility adapt changes business environment ability work general guidance broad assignments . ability take direction easily , interpret directives execute efficient manner highly organized detail oriented adheres high standard core values ethics align organization . maintains high integrity trust strong interpersonal oral communication skills , including speaking clearly confidently communicating levels stakeholders support staff senior level executives proficient use personal computers various software packages , including ms sharepoint , word , excel powerpoint currently enrolled college seeking qualifying degree bachelor ’ degree business administration , related field prior knowledge principles practices business , operations management , project management coursework and/or practical experience work hours conditions : 40 hours monday – friday ( 8:00-5:00 pm ) . overtime may required needed basis security sensitive position . federal law , position requires candidates u.s. citizen . proud equal opportunity employer .',
#  "aviall world 's largest provider new aviation parts related aftermarket services . aviall markets distributes products 240 manufacturers offers approximately 2,000,000 catalog items 40 customer service centers located north america , europe , asia-pacific . aviall prides open‚ performance–based culture throughout organization . offer environment diverse , challenging supportive , provides hands-on experience real-world responsibilities serves springboard successful career . also proud consistently receive outstanding awards diversity recruitment efforts including “ top 100 military-friendly employers. ” come join talented world class team thrive dynamic supportive culture . position summary : aviall exciting position sales intern corporate headquarters located dallas , tx . sales intern assist department various information technology initiatives may include limited : data analytics , logistics , pricing reporting skillset focus efficiency opportunity scenarios within group . additionally internship provides opportunity build relationships develop business acumen networking aviall interns across enterprise interaction various aviall leaders . expected starting date position may 15 , 2017. job requirements qualifications : completed first semester junior year first semester master ’ program may 15 , 2017. overall gpa 3.0. good presentation , speaking , organizational , problem solving skills , thorough attention detail , capability meet deadlines . ability adapt change willingness flexible global team environment . excellent written communication skills ability document technical information easy understand straightforward manner . aviall equal opportunity employer . employment decisions made without regard race , color , religion , sex , sexual orientation , gender identity , national origin , disability , veteran status characteristics protected law . education college coursework completed",
#  'organizational summary : part nation ’ central bank , federal reserve bank dallas committed strengthening economy communities . fed , opportunity become part important public service institution whose work touches lives across globe . ’ big job ’ need talented , results-driven professionals care making difference . position summary : human resources analyst intern assist hr department building human capital data analytics practices ensuring aspects human resources represented . role , intern opportunity partner compensation , payroll , hris , recruiting onboarding build implement tools processes help department successfully solve data-driven challenges . responsibilities : conduct research industry benchmark hr metrics develop metrics hr include limited : turnover , compensation , recruitment diversity work closely key hr units business areas develop additional reports part internal projects include comprehensive analysis trends , kpi metrics , predictive analytics partner hris research best delivery methods reports , forms , documents , etc . create samples user approval education experience : •1 years experience analysis and/or reporting role •working knowledge ms excel , including ability utilize following functions : v-lookup , h-lookup , concatenating formulas , conditional formatting , pivot tables •must proactive solutions oriented business professional ability interface levels management across business units functions •must ability handle sensitive information highest degree integrity confidentiality • junior ( higher ) pursuing degree human resources , business related field work hours conditions : 40 hours monday – friday ( business hours 8am 5pm ) proud equal opportunity employer .',
#  'atos leader digital services annual revenue € 12 billion 100,000 employees 72 countries . serving global client base , atos offers consulting & systems integration , managed services & bpo , cloud , big data & cyber-security solutions . deep technology expertise industry knowledge , atos works clients across many business sectors : defense , financial services , health , manufacturing , media , utilities , public sector , retail , telecommunications , transportation.atos focused business technology powers progress helps organizations create firm future . addition , atos worldwide information technology partner olympic & paralympic games operates brands atos , bull , canopy , unify worldline . atos offers broad professional perspective opportunity build rewarding career across either technical business paths . worldwide presence broad range professional services , atos provides training programs across competencies markets worldwide employees stages career . addition , offer programs focused engaging developing people beginning career internships graduate opportunities . information , please see atos corporate web site : www.atos.net . atos eeo employer , providing employment opportunity regardless race , color , religion , sex , age , national origin veteran status , disability factors protected law . summer intern position highly motivated independent intern join outsourcing presales team . intern responsible designing developing reports interactive dashboards utilized organization . successful candidate proven self-learning abilities , motivation , strong data analytics knowledge , exceptional problem solving skills attention detail.responsibilities : - work cross-functional teams , gather , analyze document reporting requirements meet business needs.- translate business requirements specifications used implement required reports interactive dashboards , created potentially multiple data sources.- design , develop , deploy tableau interactive dashboards.- validation testing critical business reports.- closely monitor check accuracy completeness data tableau . perform optimization tableau reports . minimum qualifications : - excellent communication skills , written oral - comfortable ambiguity , change , working agile manner . - ideal candidate must self-starter detail-oriented professional work independently . - must outstanding organizational verbal written skills - proficiency microsoft office suite required including strong excel skills - familiarity microsoft access sharepoint preferred qualifications : - hands-on sql database experience . - knowledge business intelligence / analytics tools like business objects , tableau similar data mining service , ability write variables understand scripts . - data mining , statistics analytical modeling . - must currently enrolled college technical institute graduated within 6 months internship- high degree interest it- internships intended positions limited duration , maximum duration ten months ( 1560 hours per year max ) . - effective communication interpersonal skills ( written verbal ) - ability work team - background checks required interns',
#  'job details intern - business analytics us - texas - dallas , us - texas , usa apply job reference . 231127 country usa region us - texas city us - texas - dallas position type student job area job type part time > 50 % company atos company information atos leader digital services annual revenue € 12 billion 100,000 employees 72 countries . serving global client base , atos offers consulting & systems integration , managed services & bpo , cloud , big data & cyber-security solutions . deep technology expertise industry knowledge , atos works clients across many business sectors : defense , financial services , health , manufacturing , media , utilities , public sector , retail , telecommunications , transportation.atos focused business technology powers progress helps organizations create firm future . addition , atos worldwide information technology partner olympic & paralympic games operates brands atos , bull , canopy , unify worldline . atos offers broad professional perspective opportunity build rewarding career across either technical business paths . worldwide presence broad range professional services , atos provides training programs across competencies markets worldwide employees stages career . addition , offer programs focused engaging developing people beginning career internships graduate opportunities . information , please see atos corporate web site : www.atos.net . atos eeo employer , providing employment opportunity regardless race , color , religion , sex , age , national origin veteran status , disability factors protected law . job description summer intern position highly motivated independent intern join outsourcing presales team . intern responsible designing developing reports interactive dashboards utilized organization . successful candidate proven self-learning abilities , motivation , strong data analytics knowledge , exceptional problem solving skills attention detail.responsibilities : - work cross-functional teams , gather , analyze document reporting requirements meet business needs.- translate business requirements specifications used implement required reports interactive dashboards , created potentially multiple data sources.- design , develop , deploy tableau interactive dashboards.- validation testing critical business reports.- closely monitor check accuracy completeness data tableau . perform optimization tableau reports . job requirements minimum qualifications : - excellent communication skills , written oral - comfortable ambiguity , change , working agile manner . - ideal candidate must self-starter detail-oriented professional work independently . - must outstanding organizational verbal written skills - proficiency microsoft office suite required including strong excel skills - familiarity microsoft access sharepoint preferred qualifications : - hands-on sql database experience . - knowledge business intelligence / analytics tools like business objects , tableau similar data mining service , ability write variables understand scripts . - data mining , statistics analytical modeling . additional information - must currently enrolled college technical institute graduated within 6 months internship- high degree interest it- internships intended positions limited duration , maximum duration ten months ( 1560 hours per year max ) . - effective communication interpersonal skills ( written verbal ) - ability work team - background checks required interns apply job back search results',
#  "job descriptions : downtown agency looking rockstar digital marketing intern . working alongside team second none latest greatest marketing trends digital world . familiar industry paid , owned , earned media concepts , understanding digital marketing data used drive channel . familiar reporting excel hacks would also beneficial . born superpowers , heard professors colleagues discussing booming trend , looking join us . : work closely digital marketing team coordinate account managers , web developers , creative strategy teams.activities would include keyword research , content production optimization , data analysis , quality assurance testing , opportunity identification , troubleshooting technical issues.manage execute day-to-day tactical seo & ppc strategies.take part client meetings discussing facets digital marketing campaigns.develop present internal monthly reports leverage data demonstrate impact company 's digital marketing services time.invent , design , test , analyze , optimize , scale roi-positive seo , ppc content marketing initiatives.work alongside social media channels work together seo.required experience : knowledge seo ( search engine optimization ) knowledge ppc ( pay-per click ) management.analytically inclined.data oriented - excel wizard sorts.outstanding problem solving skills.self-starter ability work independently small team.outstanding written verbal communication skills.an understanding html , css , java script , databases general website architecture.experienced content strategy , creation optimization.email marketing , cms crm experience great bonus.keyword : digital marketingfrom : 70kft",
#  'job title data analyst - intern job summary data analyst partner business understand business needs facilitate flow data stearns ’ loan origination system business intelligence system . addition , responsible maintaining integrity data , well documenting appropriate use data across corporation . analyst primary responsibility filing quarterly mortgage call compliance reports multiple entities , using cognos database . work closely management end-users evaluate business requirements support delivery effective business intelligence reporting solutions . job functions analyze transactional level data excel and/or access check data gaps issues . could include , limited missing data , duplication data , incorrect irrelevant data.respond business inquiries related data entered loan origination systemaudit reports accuracy , consistency completeness . interface report users ensure reports meet business needs . perform data quality management activities including data profiling , data validation , assessing data relevancy improve information reliability.gather analyze relevant source data work appropriate personnel address unexpected results.identify data content , anomalies , support business requirements thorough data analysis profiling.create maintain documentation processes , reports , applications , proceduresserve group ’ sme metadata , including definitions , business data quality rules , sourcing performance.review business definitions documents , collect , analyze information preparation setting format load data warehouse.audit maintain reporting requirements quarterly filing mortgage call report state regulatory exams.maintain records data supplied regulators / third-parties . job requirements proficiency excel ms sqlbachelor ’ degree computer science related fieldstrong attention detail ; ability manipulate large pools data accuratelyexperience using ibm cognos microsoft access plus',
#  'passionate technology-enabled change real world application ? ready take academic education next level ? join business technology analyst summer scholar program , learn bridge theoretical practical immersive , fast paced work environment . summer scholars leverage strategic thinking foundational business technology skills advise clients , cut complexity , inspire value-driven decisions collaborative team setting . work ’ doas business technology analyst summer scholar , opportunities make impact broad range transformative projects clients . support delivery various types client deliverables range information management solutions implementations large scale technology platforms supporting development advisory materials technical architecture operating models . please see technology service offerings learn work every day help solve client ’ challenging problems . capitalize cross industry presence find niche begin building individual brand.while career consulting dynamic evolving , look people perform certain areas , grow related skills deliver exceptional results clients . recognize unique skills , experiences , interests , divide broad scope bta intern role skills-based segments order best align bta intern focus area . segments function subgroups interns analysts leverage network enhance professional development . setting people success highest priority.we currently recruiting business technology analyst summer scholars whose skills interests align one following areas : • technology design & development : analyst skilled programming prepared jump technical role . top performer computer science , software engineering mis proficient one programming languages additional experience interest areas app development , user interface/wireframe design , server side development , os languages ( windows , linux ) and/or basis/abap . potential project roles may solution architect analyst , software developer , database administrator qa tester.• data analytics : analyst knowledgeable interest across wide range analytics data transformation tools able transform client data meaningful , actionable insights . comfortable emerging trends discipline versatile ( technically functionally . ) potential project roles may big data developer , data scientist , data management analyst/tester , data visualization engineer , data transformation designer/tester analytics organization assessment analyst.the teamour technology consulting team plays major role directly embedding technology insights clients ’ organizational goals . deloitte , technology consultants create sharply-focused solutions within organization ’ operating model , accounting people , intellectual capital , technology , processes . engagement teams deloitte drive value clients also understand importance developing resources contributing communities work . make business take issue impact , within beyond client setting . learn technology consulting practice.required qualifications• junior standing full-time academic program target graduation date december 2017 june 2018• undergraduate following related majors : technology science : computer science , computer information systems , management information systems , network administration/security , operations/administration , data analytics , matho business : accounting , analytics , business , economics , finance , marketing , operations , statistics , supply chaino engineering : computer engineering , electrical engineering , engineering management , industrial engineering , software engineering , systems engineering• strong academic track record ( minimum gpa 3.4 ) • demonstrates interest aptitude technology• willingness travel • availability participate summer scholar program full-time , approximately 10 weeks june august 2017how ’ growthroughout course internship program , ’ receive formal informal mentorship training . business technology analyst summer scholar training program provides view technical skills well critical professiona ...
#  'real-world experience . life-long connections . intern us.team seasoned healthcare technology professionals expand real-world knowledge base . spend 12 weeks make lifetime difference , interacting interns.the data scientist intern work data & analytics team . looking individual pursing degree information technology , computer engineering , computer science , related major . summary duties intern expect perform working mentor summer hms.this role take one existing business processes apply data science techniques machine learning either match improve current performance . intern need collaborate stakeholders understand process desired improvements . heavy data engineering work already done , job require data wrangling feature engineering prepare machine learning . model selected , rationale decision model need explained business stakeholders . pythonsqldata wranglingfeature engineeringmachine learningmodel evaluationdata visualization',
#  'requisition number 17-0014 post date 4/13/2017 title digital marketing intern city dfw airport state tx job group marketing description marketing internships- grapevine , texas - http : //www.dexmedia.com/ dex media looking marketing interns ! dex media ’ summer intern program full-time , 3 month paid internship open junior , senior graduate program students . : • digitally savvy • talented hard-working • organized detail-oriented • love creativity marketing • ’ smart enough know ’ know , eager listen , learn grow • driven , ambitious innovative • enjoy part team marketing assignments available grapevine , tx location : • corporate communications corporate/employee communications writing social media • marketing communications branding copywriting/proof reading video production email development - html graphic design ( indesign , photoshop ) • customer relationship management ( crm ) driving client engagement app messaging ab testing drive end user engagement • digital marketing digital product marketing content writer data analyst web developer • journalist writer digital , mobile , internet • marketing analyst utilize database knowledge , programming skills data manipulation / query tools produce actionable data used support marketing sales . consult internal teams define requirements timelines ensure timely accurate delivery data elements tools required projects initiatives . summarize communicate progress , processes , insights recommendations via summary documents presentations support management decision-making . requirements • 0-1 year experience • junior , senior graduate students available work june -august full-time hours , monday – friday , 8:30am – 5:30pm grapevine , tx location . • students pursuing degree marketing , digital marketing , marketing analytics , journalism social media , communications , advertising , journalism , pr , english , related field . • basic knowledge relational databases ms access , oracle , sql server sql marketing analyst position . • students must demonstrated leadership throughout college career . • must detail-oriented organized • must proficient skills using social media , microsoft office suite , knowledge adobe suite helpful . • video production editing experience preferred ( applies video assignment ) • strong eye details • understanding marketing strategies , digital advertising , branding industry trends • good presentation skills • excellent oral written communication skills • must exhibit excellent writing interpersonal skills dex media dedicated working local businesses provide powerful marketing solutions . marketing solutions leader trusted local business clients nationwide . ’ committed helping clients create grow customer relationships providing custom mix marketing solutions include websites , print , mobile , social media search engine marketing . passion delivering highest quality solutions best value help businesses sizes meet goals . http : //www.dexmedia.com/ dex media equal opportunity employer .',
#  'position qualifications clerical internship - paid summer 2017 brinks – coppell texas 75019 $ 15 - $ 17 hour - temporary , internship40 hours/5 day week preferred overview : internships 10-12 week summer program , starting june , allows college seniors perusing mba opportunity develop skills exposure learn drive new revenue large business . seek provide rewarding opportunity interns develop technical , management leadership skills outside classroom.responsibilities : • interns encouraged develop administrative , analytical technical writing skills supporting global team new project proposals , marketing pursuits , production analysis presentation documents• manage calendar scheduling meeting requests• assist data entry system files • compose transmit routine correspondence• coordinate arrange meetings , prepare agendas , prepare facilities• prepare outgoing mail correspondence , including e-mail faxes• manage office inventory supplies• organize maintain file system• assist various projects assignedqualifications : • candidate must college senior pursuing bachelor degree business marketing• student must good academic standing overall gpa 3.0 better• prior related business marketing experience preferred• strong communication skills proven time management• ability adapt various situations – work fast paced environment , flexible resourceful• demonstrate leadership take lead little guidance – work independently• builds rapport interact professionally various business partners levels• critical thinking creative program solving skills• team-oriented strong partnership skills• working knowledge microsoft outlook excel , particular emphasis list lead brink ’ sbrink ’ global leader security logistics services , trusted banks , financial institutions businesses public private sectors . deliver currency world businesses communities . ’ needed . ’ trusted valued . makes us proud . brink ’ proud . equal opportunity employer discriminate employee applicant employment race , color , sex , age , national origin , religion , sexual orientation , gender identity , status veteran , basis disability federal , state local protected class .',
#  "aviall world 's largest provider new aviation parts related aftermarket services . aviall markets distributes products 240 manufacturers offers approximately 2,000,000 catalog items 40 customer service centers located north america , europe , asia-pacific . aviall prides open‚ performance–based culture throughout organization . offer environment diverse , challenging supportive , provides hands-on experience real-world responsibilities serves springboard successful career . also proud consistently receive outstanding awards diversity recruitment efforts including “ top 100 military-friendly employers. ” come join talented world class team thrive dynamic supportive culture . position summary : aviall exciting position business strategy intern corporate headquarters located dallas , tx . business strategy intern opportunity focus key project series projects support strategic initiatives . additionally internship provides opportunity build relationships develop business acumen networking aviall interns across enterprise interaction various aviall leaders . expected starting date position may 15 , 2017. responsibilities : assists preparation business-related analyses one following areas : planning forecasting , workload/capacity planning , product performance , campaign performance , process performance , financial impact analysis member behavior analysis . participates providing input definition business problems opportunities development data analytical requirements . assists data aggregation representation provides input articulate key messages . performs financial forecasting , competitive intelligence , business planning and/or business problem analysis . assists business case development , including gathering requirements , analyzing business trends , researching historical data , reviewing industry standards , recommending presenting solutions . completes assigned project ( ) develop executive level presentation deliver senior leaders . performs tasks assigned . job requirements qualifications familiarity use microsoft office products software used develop analysis , charts , learning modules and/or supporting documentation . completed first semester junior year first semester master ’ program may 15 , 2017. actively pursuing bachelor 's master 's degree business , marketing , finance , statistics , information systems related field study . overall gpa 3.0. ability conduct in-depth industry research , define market trends , interpret financial data . solid understanding business market analysis , financial acumen , marketing . strong analytical problem-solving skills . excellent oral written communication skills ; experience making presentations communicating ideas plans management . education college coursework completed",
#  'please apply position/location interested . order considered position must : 1. apply job portal ( including resume transcript ) 2. apply grant thornton job portal www.grantthornton.com/campuscareers ( including resume transcript ) grant thornton ? grant thornton collaborative , entrepreneurial firm move ! part dynamic , global organization 42,000 people serving clients 120 countries , agility focus takes leader . founded chicago 1924 , grant thornton llp ( grant thornton ) u.s. member firm grant thornton international ltd , one world ’ leading organizations independent audit , tax advisory firms . grant thornton revenue excess $ 1.56 billion operates 58 offices across united states 565 partners 8,000 employees . grant thornton works broad range publicly privately held companies , government agencies , financial institutions , civic religious organizations . core industries served include consumer industrial products , financial services , not-for-profit , private equity , technology . grant thornton focuses serving dynamic organizations pursue growth holistically – whether revenue improvement , leadership , mission fulfillment innovation . committed capitalizing strengths serving dynamic organizations share values drive . global values collaboration , leadership , excellence , agility , respect , responsibility ( “ clearr ” ) guide behaviors fuel ambition firm makes difference every day . provide companies guidance need help run businesses , establish robust internal controls , use information effectively improve performance . services include compliance , consulting services , information technology solutions , forensic accounting investigative services , recovery reorganization , tax preparation , valuation , name . risk advisory services ( ras ) ? digitization currencies , transactions , relationships , experiences assets transformed entire industries . cyber capabilities extend borders reach , creating new customers , business partners , avenues access , methods innovation forms value . time , ongoing disruption marketplace competitive regulatory landscape presents continually evolving strategic , operational , financial risks . move forward challenging environment , many management teams turning advisers like grant thornton llp broader industry business perspectives proven experience assist developing implementing risk management programs . dynamic organizations embrace risk grant thornton risk advisory services professionals ready help identify protect key assets transforming risk driver growth organization . risk-adept management teams effectively : predict deploying advanced analytic tools , technologies processes anticipate address risks become problems.prepare embracing broader , deeper , holistic approaches place risks strategic context empower improved decision making.protect establishing sustainable lines defense firmly linked business strategy.manage optimizing compliance function people , processes technologies incorporate risk management best practices industry . respond preparing unexpected finely tuned , frequently tested in-house external response mechanisms teams.why become ras intern ? ras interns gain exposure various areas practice participating active member risk consulting compliance projects becoming integral part delivery teams . ras intern primary responsibility executing high quality ras projects services beginning end supervision experienced ras leadership . responsible efficiently managing workload budget learning apply technical skills across various consulting services . ras intern ’ opportunities build client relationships developing deep understanding clients ’ businesses deliver value insight quality work . addition , ras intern ’ focus continuously developing technical professional skills grow expand role ras practice . additional responsibilities may include : performing detailed analysis identify assess compliance opportunities improvement , documenting conclusions , providing recommen ...
#  "position summary internship information technology services ( ) kick start career journey . throughout internship program , 'll gain real business experience working projects , build upon skillset ( technical soft skills ) , expand network . immersing culture , learn takes succeed within professional services firm along way , discover exciting career opportunities . work ’ dothe global employee services intern involved hands designing , coding , enhancing testing data models meet business process requirements . apply functional knowledge technical expertise aspects relational database design . dba associate primary skilled sql , data modeling , data management tools ssrs reporting . creating value clients : • design implementation analyses identify requirements related people , processes technology• development technical design documents ( specifications ) based functional design documents ( business requirements ) • design develop applications based technical/functional design documents . includes hands involvement designing , coding testing program modules• assess resolve non-standard/standard issues/problems largely initiative demonstrating business operations capability : • create data dictionary organizer , calendar , itracker , mobility management• create etl ( extract transform load ) proof concept using informatica ( etl tools ) loading data various external internal sources data warehouse• set poc environments• create data warehouse• create transformation configuration test inputs teamas information technology services intern , ’ opportunity work one four service lines : deloitte applications studios ( das ) , technology infrastructure ( & ) , cybersecurity , technology management operations ( tmo ) . ’ get chance work experienced team projects build technical business skills help clients achieve higher level service operational efficiency business value . depending role , ’ opportunity engage cyber risk detection prevention , web/mobile application design development , web hosting , database administration management , overall business operations . culture embraces diversity , inspires innovation , supports everyone maximizing potential workplace . ’ joining team highly talented people collaborate deliver cutting edge technology solutions ; whether ’ developing custom enterprise applications providing infrastructure support , ’ play critical role helping business stay ahead curve . analytical skills needed parse mountains data , technical proficiency deliver custom solutions , interpersonal skills present thoughts technical non-technical audiences logical meaningful ways . qualificationsrequired : • candidate bachelor degree technology related major minor ( sophomore junior standing ) • ability work among multiple teams communicate effectively technical non-technical team members• willing reside nashville , tennessee greater area duration internship• possess excellent verbal written communication skills• motivated self-starter • extremely attentive detail• organized diligent strong time management skills • proficient microsoft office• manage work product , schedules deliverables• assigned accountable specific areas responsibility/deliverables . • ability identify , assess provide resolution complex issues problems.• makes decisions within parameters set manager , using job experience.• seeks advice escalates issues faced tasks/problems outside normal scope job . preferred : • strong academic track record ( minimum 3.2 gpa ) • sql server• etl tools• data modeling tools• open source frameworks• content management systems• configuration management ’ growthroughout internship program , want give true taste life deloitte . means lot support - formal informal - right start . guided coaches mentors help learn deloitte opportunities , 'll gain real-world experience working meaningful projects . beyond exposure “ real life ” projects , program also delivers variety national local learning networking events . regularly sched ...
#  'company description : want work something really matters impacts everyone us ? medeanalytics sits intersection healthcare , technology , big data , national policy . mede made inspired people vast industry knowledge . committed mission providing clear , human-powered insights transform healthcare . goal lower overall cost healthcare using data analytics workflow applications reduce inefficiencies , facilitate communication increase transparency . think money ball hospitals . 1000 healthcare organizations use cloud based , software-as-a-service ( saas ) products every day ’ looking smart people help us double number change healthcare industry . company privately held high-energy work environment rewards innovation represents tremendous personal growth opportunity right professional . proud say mede one modern healthcare ’ 100 best places work healthcare . role profile : data quality interns work closely engineers business analysts build maintain big data systems large scale , high performance , rock-solid reliability maintaining highest standard quality completeness . hands-on position require performing quality assurance practices exciting dynamic medical fields . essential duties responsibilities : work engineering product teams distributed across multiple locations work business analysts , product owners engineers analyzing understanding requirements create execute test cases create analyze defect tracking reports regular basis effectively document communicate results duties required business conditions assigned required skills interest quality assurance/testing proficient ms excel understanding software development life cycle strong communication skills ( written verbal ) ability work effectively team results-oriented , self-motivated quick-learner pursuing associates/bachelors/masters degree ( , mis , healthcare degree equivalent ) strongly desired . desired knowledge/skills knowledge agile methodology knowledge jira project tracking software knowledge healthcare industry preferred knowledge sql preferred special requirements based dallas , tx working environment : work environment characteristics described representative employee encounters performing essential functions job . reasonable accommodations may made enable individuals disabilities perform essential functions . performing duties job , employee regularly works near office equipment ( telephone , computer ) employees . employee works normal office conditions physical discomfort due temperature , dust , noise , etc . verbal written communication , telephone usage , filing , sitting , typing , driving , reading carrying required perform essential functions job .',
# ...
#  'real-world experience . life-long connections . intern us.team seasoned healthcare technology professionals expand real-world knowledge base . spend 12 weeks make lifetime difference , interacting interns.the business analyst intern work team . looking individual pursing degree mis , management , related major . summary duties intern expect perform working mentor summer hms.review , analyze , evaluate data/systems business requirements development effortsperform analysis implementation enhancement effortsprovide data mapping , specifications processing logic per business requirementsassist testing efforts development staff clientserve liaison developers internal/external clientsprovide status reports clients , developers , management needed good communication skillsproject management skillsgood analytical skills',
#  'internship program paid internship program designed educational engaging opportunity students work challenging projects help us achieve mission goals . students experience emersion corporate life training , access leaders , social events , mentoring , capstone project presented senior management . position information title : marketing & analysis intern flsa : hourly / temporary division name / location : corporate office / grapevine , tx department name : sales & marketing hours : flexible 35-40 hours / week supervisor title : assistant director , sales & marketing operations rate pay : $ 14 / hour doe principal activities : position following accordance applicable federal , state local laws / regulations companys policies , procedures guidelines : assist creating maintaining database sales assist preparing reports business plan forecast assist creating reports bi-annual market share reviews , reports sales directed analyze data create queries and/or reports support regional sales management provide information division spending assist mapping reports dealer performance , industry performance overall product sales complete special projects needed duties assigned minimum qualifications : must actively enrolled undergraduate program accredited local university , junior senior working toward bachelors degree economics , finance degree demonstrated relevant experience perform job duties . gpa 3.0 . advanced excel skills , sap knowledge plus ; intermediate level power point general computer skills . strong interpersonal ( verbal/written ) communication skills . high level skill decision making , problem solving analytics . organizational , multi-tasking prioritization skills . integrity , accuracy , dependability , detailed oriented . language requirements : strong proficiency sophistication use english written verbal formats . physical requirements : physical requirements : typical office environment ( business casual ) . position require walking , standing sitting computer . benefits student : comprehensive training access top leaders capstone project presented senior management events throughout summer including lunch & learns , social events engaging independent work makes difference business build resume explore post-graduation career options real world experience interviewing practice potential future employment information provided description designed indicate general nature level work performed incumbents within classification . description intended comprehensive inventory duties , responsibilities , qualifications working conditions required employees assigned job/classification . management reserves right add modify duties responsibilities designate functions essential time . perform job successfully , individual must able perform essential duty satisfactorily . minimum qualifications listed representative knowledge , skill , and/or ability required . reasonable accommodations may made enable individuals disabilities perform essential functions . consistent applicable federal state law , kubota committed providing equal employment opportunity applicants employees . discriminate qualified applicant employee based race , color , ancestry , sex ( including pregnancy , childbirth related medical condition ) , sexual orientation , national origin , religion , creed , marital status , disability , medical condition , age , citizenship status , veteran status , basis protected applicable law.posted startwire',
#  "analytical thinker passion actuarial sciences interest helping organizations solve complex actuarial business problems interpreting large data sets ? 're looking business analyst intern work human capital actuarial team . 'll help build financial mathematical models improve organizational performance . start , 'll involved multiple project teams clients may include insurance companies , employers , governments . work 'll work interesting complex , quantifying risk via statistical methods part , wo n't way add value clients ' businesses . opportunity serve clients strategic operational capacities based extensive exposure clients deep analytical strengths . team human capital professionals specialize actuarial services apply advanced quantitative analysis wide range business challenges . use leading-edge statistical methods quantify risk health , life , p & c , retirement plans clients . learn human capital actuarial practice . qualifications required * enrollment bachelor 's master 's degree program related field study * strong academic track record ( minimum gpa 3.2 ) * proficiency word processing , spreadsheet , presentation creation tools , well internet research tools * demonstrable interest taking soa cas actuarial exams , least one exam passed * excellent communication skills * willingness travel 'll grow two important tools today 's business world experience resources . deloitte , 'll find plenty . 8-10 week long learning experience , 'll gain first-hand insights technical skills , critical professional behaviors , standards , mindsets needed effective actuarial consultant . 'll work wide variety talented , strategic leaders , learn leverage data statistics , tackle real-world business challenges , experience day-to-day responsibilities opportunities exciting , forward-facing career . tailored training program start day 1 supplemented learning opportunities throughout summer , whether job , virtual , office fridays . summer also feature networking opportunities firm leadership interns across organization national summer intern conference deloitte university . explore deloitte university , leadership center . deloitte 's culture positive supportive culture encourages people best work every day . celebrate individuals recognizing uniqueness offering flexibility make daily choices help healthy , centered , confident , aware . offer well-being programs continuously looking new ways maintain culture people excel lead healthy , happy lives . learn life deloitte . corporate citizenship deloitte led purpose : make impact matters . purpose defines extends relationships clients , people communities . believe business power inspire transform . focus education , giving , skill-based volunteerism , leadership help drive positive social impact communities . learn deloitte 's impact world . recruiter tips want job seekers exploring opportunities deloitte feel prepared confident . help interview , suggest research : know background organization business area 're applying . also suggest brush behavioral case interviewing skills practice discussing experience job history family member , friend , mentor . check recruiting tips deloitte professionals . requisition code : s17cbscf17junjm-hcposted startwireapply",
#  'internship program paid internship program designed educational engaging opportunity students work challenging projects help us achieve mission goals . students experience emersion corporate life training , access leaders , social events , mentoring , capstone project presented senior management . position information title : turf marketing intern flsa : hourly / temporary division name / location : grapevine , tx department name : ag & turf hours : flexible 20-35 hours / week supervisor title : director turf principal activities : position following accordance applicable federal , state local laws / regulations companys policies , procedures guidelines : assist ag & turf department special projects , research , compiling data , creating training materials , analysis . generate reports regarding sales incentive programs learn margin reports support decision making . learn analyzing marketing proposals programs enable sales executive management evaluate programs effectiveness . perform pre-analysis programs provide information determining best cost effective programs prior implementation . exposure roi reports advertising direct mail promotional campaigns well sponsorship participation , merchandising , industry trade shows , lead generation . exposure crm database program , including direct mail customer newsletter mailing lists . learn ongoing crm recommendations promotional programs . learn effectiveness web-based communications create monthly reporting system results . analyze , plan , execute database marketing strategies customer campaigns including research , documentation , scope analysis , business case creation . coordinate customer satisfaction manager development management customer-segmentation , customer profiling , data modeling crm programs . work telemarketing firms , call centers , print , direct mail houses apply assimilate data , including response analysis , ensuring adherence state federal regulations . partake strategy planning implementation develop turf equipment dealerships se division market . help facilitate turf department preparation dealer marketing events include open houses events . take active role preparing , setting-up , attending representing kubota , industry trade shows local area . mentor turf sales field staff accompanying visits dealer principals dealership personnel respective territories . assist department streamlining improving development training activities tools . interact dealer network conducting phone calls sales , service parts promotional purposes , conduct product service surveys , etc . assist participate division events . provide administrative support turf department . complete special projects needed duties assigned . minimum qualifications : must actively enrolled undergraduate program accredited local university , junior senior working toward bachelors degree business , general agriculture , agribusiness , ag communications , ag mechanization , english , marketing , communications , advertising degree demonstrated relevant experience perform job duties . 3.0 skills background : strong capability microsoft office suite include power point , excel word ; access skills preferred ; able develop ad slicks , reports , training materials ; experience administering facebook updates using social media resources . basic knowledge office machines strong interpersonal ( verbal / written ) communication skills . ability communicate various levels management . high level skill decision making , problem solving analytics . organizational , multi-tasking prioritization skills . integrity , accuracy , dependability , enthusiasm confidentiality must authorized work united states without visa sponsorship language requirements : strong proficiency sophistication use english written verbal formats . physical requirements : ability lift least 30 pounds benefits student : comprehensive training access top leaders capstone project presented senior management social events throughout summer ...
#  "want jump start career take business skills next level joining deloitte 's team ? chance get head start graduate . join group interns 'll get inside look 's really like work professional services organization . work 'll position , assigned group within one internal services group . 'll gain real-world experience working meaningful projects . opportunity collaborate consult deloitte professionals . 'll use exceptional organizational skills meet deadlines work diverse groups locally nationally based professionals . responsibilities role could include following : * manage potential list invites annual corporate finance conference including broader deloitte network , private equity firms sought participants . * refine conference invite list looking key information database . * track referred companies deloitte professionals part roll onedeloitte referral program . * partner business development committee commence database mining project designed assign classification naic codes prospective companies 'll grow throughout course internship program , receive formal informal mentorship training . access learning opportunities help foster accelerate development new skills capabilities . beyond formal training , work talented professionals chance ask questions gain valuable hands-on experience working client engagements . qualifications required * open students interested field study * keen interest professional services * professional demeanor strong communication skills , written oral * demonstrated leadership qualities leadership potential * ability work independently within team culture * ability quickly concisely collect report data preferred * 3.2 cumulative gpa strongly preferred team corporate finance team assists clients financial strategic advisory include sellside buyside & , capital raising , evaluation corporate finance alternatives including employee stock ownership plans ( `` esops '' ) . interns work collaborative environment real-time performance feedback encouraged given responsibilities based performance capability . opportunities full-time positions may available high performers . learn corporate finance practice . deloitte 's culture positive supportive culture encourages people best work every day . celebrate individuals recognizing uniqueness offering flexibility make daily choices help healthy , centered , confident , aware . offer well-being programs continuously looking new ways maintain culture people excel lead healthy , happy lives . learn life deloitte . corporate citizenship deloitte led purpose : make impact matters . purpose defines extends relationships clients , people communities . believe business power inspire transform . focus education , giving , skill-based volunteerism , leadership help drive positive social impact communities . learn deloitte 's impact world . recruiter tips want job seekers exploring opportunities deloitte feel prepared confident . help interview , suggest research : know background organization business area 're applying . also suggest brush interviewing skills practice discussing experience job history family member , friend , mentor . check recruiting tips deloitte professionals . requisition code : s17dalfi18julkw-cfposted startwire"]

# %% [markdown]
# ### Step 3: Extract Skills Using Named Entity Recognition (NER)
# #### 📌 Goal: Use spaCy’s built-in NER to detect and extract skills from job descriptions.
#
# 1. Load spaCy’s English model.
# 2. Use NER to identify important keywords.
# 3. Extract words related to technical skills, tools, and expertise.

# %%
len(preprocessed_descriptions)
# Out:
# 157

# %%
# your code here
import spacy
nlp = spacy.load('en_core_web_sm')
skills = []
for description in preprocessed_descriptions:
  doc = nlp(description)
  for ent in doc.ents:
    # print(ent)
    if ent.label_ == 'PRODUCT':
      skills.append(ent.text)
    if ent.label_ == 'JOB':
      skills.append(ent.text)

skills
# Out:
# ['•',
#  '401k',
#  '401k',
#  'perspective.experience',
#  'perspective.experience',
#  '•',
#  '•',
#  '•',
#  '•',
#  '•',
#  '•',
#  'pbxs',
#  'microsoft visio',
#  '•']

# %%
# your code here
import spacy
from spacy.matcher import PhraseMatcher

nlp = spacy.load('en_core_web_sm')

# A sample list of known technical skills/tools – customize this
skill_list = [
    "Python", "TensorFlow", "Keras", "PyTorch", "Docker", "Git", "SQL",
    "Java", "C++", "AWS", "GCP", "Azure", "Pandas", "NumPy", "Scikit-learn"
]

# Initialize matcher
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
patterns = [nlp(skill) for skill in skill_list]
matcher.add("SKILL", patterns)

skills = []

for description in preprocessed_descriptions:
    doc = nlp(description)

    # Rule 1: Use NER for PRODUCT entities
    for ent in doc.ents:
        if ent.label_ == 'PRODUCT':
            skills.append(ent.text)

    # Rule 2: Use PhraseMatcher
    matches = matcher(doc)
    for match_id, start, end in matches:
        skills.append(doc[start:end].text)

# # Optional: deduplicate and normalize
skills = list([s.strip().lower() for s in skills])

skills
# Out:
# ['sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'java',
#  '•',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  '401k',
#  '401k',
#  'java',
#  'perspective.experience',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'python',
#  'java',
#  'sql',
#  'java',
#  'sql',
#  'sql',
#  'sql',
#  'perspective.experience',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'python',
#  'java',
#  'sql',
#  'java',
#  'sql',
#  'sql',
#  'sql',
#  '•',
#  '•',
#  '•',
#  '•',
#  '•',
#  '•',
#  'sql',
#  'python',
#  'java',
#  'java',
#  'sql',
#  'java',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'java',
#  'python',
#  'sql',
#  'java',
#  'python',
#  'sql',
#  'python',
#  'sql',
#  'sql',
#  'pbxs',
#  'microsoft visio',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'sql',
#  'java',
#  'java',
#  'sql',
#  'java',
#  'sql',
#  'c++',
#  'python',
#  'java',
#  'java',
#  'sql',
#  'sql',
#  'python',
#  '•']

# %% [markdown]
# ### Step 4: Identify the Most In-Demand Skills
# #### 📌 Goal: Count the most frequently mentioned skills in job descriptions.
#
# 1. Create a word frequency distribution of extracted skills.
# 2. Identify the top 10 most required skills.

# %%
from collections import Counter

# Assuming 'skills' is your list of extracted skill names (lowercased & deduplicated per document)
# If you haven't already cleaned them:
# skills = [s.lower() for s in skills]

# Create frequency distribution
skill_freq = Counter(skills)

# Display top 10 most required skills
top_10_skills = skill_freq.most_common(10)

print("Top 10 most required skills:")
for skill, freq in top_10_skills:
    print(f"{skill}: {freq}")
# Out:
# Top 10 most required skills:
# sql: 58
# java: 16
# •: 8
# python: 8
# 401k: 2
# perspective.experience: 2
# pbxs: 1
# microsoft visio: 1
# c++: 1

# %% [markdown]
# ### Step 5: Categorize Skills by Industry
# #### 📌 Goal: Compare the most in-demand skills across different industries.
#
# 1. Group job descriptions by industry.
# 2. Extract and analyze skills for each industry.
# 3. Compare IT vs. Marketing vs. Healthcare, etc..

# %%
import spacy
from spacy.matcher import PhraseMatcher
from collections import defaultdict, Counter

nlp = spacy.load("en_core_web_sm")

# Define your skill list
skill_list = [
    "Python", "TensorFlow", "Docker", "Git", "SQL", "AWS", "GCP", "React", "SEO",
    "Google Analytics", "Content Marketing", "EMR", "HIPAA", "Patient Care", "Data Analysis"
]
patterns = [nlp(skill) for skill in skill_list]
matcher = PhraseMatcher(nlp.vocab, attr="LOWER")
matcher.add("SKILL", patterns)

# Sample job category
job_data = [
    {"industry": "IT", "description": "Experience with Python, Docker, and AWS."},
    {"industry": "Marketing", "description": "Skilled in SEO, Google Analytics, and content marketing."},
    {"industry": "Healthcare", "description": "Familiarity with EMR systems, HIPAA, and patient care protocols."},
    {"industry": "IT", "description": "Proficient in SQL, Git, and cloud platforms like GCP and AWS."},
    {"industry": "Marketing", "description": "Experienced in content marketing and SEO strategies."},
    {"industry": "Healthcare", "description": "Worked with patient care software and maintained HIPAA compliance."},
]

# skills per industry
industry_skills = defaultdict(list)

for job in job_data:
    industry = job["industry"]
    doc = nlp(job["description"])
    matches = matcher(doc)
    for match_id, start, end in matches:
        skill = doc[start:end].text.lower().strip()
        industry_skills[industry].append(skill)

# frequency distribution per industry
industry_skill_freq = {
    industry: Counter(skills) for industry, skills in industry_skills.items()
}

# top 5 for each industry
print("🔍 Top skills by industry:\n")
for industry, freq_dist in industry_skill_freq.items():
    print(f"📂 {industry}:")
    for skill, freq in freq_dist.most_common(5):
        print(f"   {skill}: {freq}")
    print()
# Out:
# 🔍 Top skills by industry:
#
# 📂 IT:
#    aws: 2
#    python: 1
#    docker: 1
#    sql: 1
#    git: 1
#
# 📂 Marketing:
#    seo: 2
#    content marketing: 2
#    google analytics: 1
#
# 📂 Healthcare:
#    hipaa: 2
#    patient care: 2
#    emr: 1
